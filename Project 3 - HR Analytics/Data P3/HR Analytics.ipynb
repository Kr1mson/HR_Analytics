# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\parth\OneDrive\Desktop\Project 3 - HR Analytics\Data P3\HR-Employee-Attrition.csv")
hr_list=df.copy()
hr_list.head()
redundant=['Over18','EmployeeCount','RelationshipSatisfaction','WorkLifeBalance','StandardHours']
hr_list.drop(columns=redundant,axis=1,inplace=True)
hr_list.drop_duplicates()
hr_list.isna().sum()
hr_list.dropna()
hr_list.describe()
#hr_list.columns
#hr_list.to_csv(r"C:\Users\parth\OneDrive\Desktop\Project 3 - HR Analytics\Data P3\HR-Employee-Attrition1.csv")
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# ...

# %%
corr_matrix=hr_list.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix,cmap='bwr', annot=True, fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_14028\278959814.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=hr_list.corr()

# %%
response_counts = hr_list['OverTime'].value_counts()
plt.bar(response_counts.index, response_counts.values, color=['red','green'])
plt.title('Overtime')
plt.xlabel('Response')
plt.ylabel('Employee Count')
plt.show()

# %%
response_counts = hr_list['MaritalStatus'].value_counts()
plt.bar(response_counts.index, response_counts.values, color=['orange','grey','blue'])
plt.title('Marital Status')
plt.ylabel('Employee Count')
plt.show()

# %%
response_counts = hr_list['JobRole'].value_counts()
plt.bar(response_counts.index, response_counts.values,)
plt.title('Job Role')
plt.ylabel('Employee Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
response_counts = hr_list['Gender'].value_counts()
plt.bar(response_counts.index, response_counts.values, color=['LightBlue','Pink'])
plt.title('Gender')
plt.ylabel('Employee Count')
plt.show()

# %%
response_counts = hr_list['EducationField'].value_counts()
plt.bar(response_counts.index, response_counts.values,color=['grey','orange'])
plt.title('Education Field')
plt.ylabel('Employee Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
response_counts = hr_list['Department'].value_counts()
plt.bar(response_counts.index, response_counts.values,color=['darkred','darkblue','darkgreen'])
plt.title('Department')
plt.ylabel('Employee Count')
plt.show()

# %%
response_counts = hr_list['BusinessTravel'].value_counts()
plt.bar(response_counts.index, response_counts.values,color=['darkgrey','yellow','red'])
plt.title('Business Travel')
plt.ylabel('Employee Count')
plt.show()

# %%
age_bins = np.arange(18, 60,5)
age_labels = [f"{start}-{start+4}" for start in age_bins[:-1]]
hr_list['Age_Group'] = pd.cut(hr_list['Age'], bins=age_bins, labels=age_labels, right=False)
grouped_data = hr_list.groupby(['Age_Group', 'OverTime']).size().unstack(fill_value=0)
grouped_data.plot(kind='bar', stacked=True)
plt.title('Overtime Preferences by Age Group (10-year intervals)')
plt.xlabel('Age Group')
plt.ylabel('Employee Count')
plt.show()

# %%
response_counts = hr_list['TotalWorkingYears'].value_counts()
plt.bar(response_counts.index, response_counts.values,)
plt.title('Total Working Years')
plt.xlabel('Years')
plt.ylabel('Employee Count')
plt.show()

# %%
response_counts = hr_list['Education'].value_counts()
plt.bar(response_counts.index, response_counts.values,color='coral')
plt.title('Education Level')
plt.xlabel('Level of Education')
plt.ylabel('Employee Count')
plt.show()

# %%
response_counts = hr_list['NumCompaniesWorked'].value_counts()
plt.bar(response_counts.index, response_counts.values,color='wheat')
plt.title('No. of Companies worked at')
plt.xlabel('No. of Companies')
plt.ylabel('Employee Count')
plt.show()

# %%
response_counts = hr_list['DistanceFromHome'].value_counts()
plt.bar(response_counts.index, response_counts.values,)
plt.title('Distance From Home')
plt.xlabel('Distance')
plt.ylabel('Employee Count')
plt.show()
